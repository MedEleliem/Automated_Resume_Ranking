# %%
from pdfminer.pdfinterp import PDFResourceManager, PDFPageInterpreter
from pdfminer.converter import TextConverter
from pdfminer.layout import LAParams
from pdfminer.pdfpage import PDFPage
from io import StringIO
import re
import nltk
import spacy
import os
from docx2pdf import convert
#import string
from nltk.stem.snowball import SnowballStemmer
nlp = spacy.load("en_core_web_sm")



def doc2pdf(path):
    
    new_path = re.sub('docx','pdf',path)
    
    convert(path, new_path)
    return new_path
    

def convert_pdf_to_txt(path):
    
    rsrcmgr = PDFResourceManager()
    retstr = StringIO()
    codec = 'utf-8'
    laparams = LAParams()
    device = TextConverter(rsrcmgr, retstr, codec=codec, laparams=laparams)
    
    interpreter = PDFPageInterpreter(rsrcmgr, device)
    password = ""
    maxpages = 10
    caching = True
    pagenos=set()
    
    base = os.path.basename(path)
    ext = os.path.splitext(base)[1]
    if ext == '.pdf':
        fp = open(path, 'rb')
        
    elif ext == '.docx':
        path = doc2pdf(path)
        fp = open(path, 'rb')
        
    for page in PDFPage.get_pages(fp, pagenos, maxpages=maxpages, password=password, caching=caching, check_extractable=True):
            interpreter.process_page(page)

    text = retstr.getvalue()
    text = re.sub('\n', ' ', text)
        
    fp.close()
    device.close()
    retstr.close()
    
    return text

def remove_StopWords(text):
    
    sentence = nlp(text)
    filtered_sentence=''
    token_list = []
    for token in sentence : 
        token_list.append(token.text)
    for word in token_list:
        lexeme = nlp.vocab[word]
        if lexeme.is_stop == False :
            filtered_sentence += ' '+word
    filtered_sentence = re.sub('é','e',filtered_sentence)
    filtered_sentence = re.sub('è','e',filtered_sentence)
    filtered_sentence = re.sub('à','a',filtered_sentence)
    filtered_sentence = re.sub('â','a',filtered_sentence)
    return filtered_sentence

def get_lem(text):
    
    text = nlp(text)
    text = ' '.join([word.lemma_ if word.lemma_ != '-PRON-' else word.text for word in text])
    return text

#def get_stem(text):
    filtered_sentence = ''    
    stemmer = SnowballStemmer(language='french')
    for token in text.split(" "):
        filtered_sentence += ' '+stemmer.stem(token)
    return filtered_sentence

        
def remove_Ent(text):
    l = ['janvier','fevrier','mars','avril','mai','juin','juillet','aout','septembre','octobre','novombre','decembre','mois','an',
         'année','jan','feb','mar','april','june','july','jul','aug','august','september','sep','oct','nov','dec']
    for i in l :
        text = re.sub(i, '', text)
    doc = nlp(text)
    text =''
    ent_type = ['PER','DATE','GPE','LOC']
    for ent in doc:
        if ent.ent_type_ in ent_type:
            text += ''
        else:
            text += ' ' + ent.text
    return text


def get_low(text):
    
    return text.lower()

def remove_SpeChar(text):
    text = re.sub('\W[a-z]\W',' ',text)
    text = re.sub('\W[a-z]\W',' ',text)
    text = re.sub(r'\w+:\/{2}[\d\w-]+(\.[\d\w-]+)*(?:(?:\/[^\s/]*))*', '', text, flags=re.MULTILINE)
    text = re.sub('\S*@\S*\s?', '', text)
    text = re.sub('\[.*?\]', '', text)
    text = re.sub(r'[^\w]', ' ', text)
    text = re.sub('[!"#$%&()*+,./:;<=>?@[\]^_`{|}~‘’•]', '', text)
    text = re.sub('\w*\d\w*', '', text)
    text = " ".join(text.split())
    return text

def main_PreProc(text):
    
    text = remove_StopWords(text)
    text = remove_Ent(text)
    #text = get_lem(text)
    text = remove_Ent(text)
    #text = get_stem(text)
    text = get_low(text)
    text = remove_SpeChar(text)
    
    return text

# %%
def lang_selec(lang):
    if lang == 'fr':
        nlp = spacy.load("fr_core_news_sm")
    elif lang == 'en':
        nlp = spacy.load("en_core_web_sm")
    return nlp

# %%
from nltk.collocations import BigramCollocationFinder
from nltk.metrics import BigramAssocMeasures

from nltk.collocations import TrigramCollocationFinder
from nltk.metrics import TrigramAssocMeasures


def tokenizer(text):
    doc = nlp(text)
    L=[]
    for token in doc : 
        if re.search(' +', token.text)==None:
            L.append(token.text)
    return L


def bigrams_(text, tokens):
    l=[]

    finder = BigramCollocationFinder.from_words(tokens)
    
    a = finder.nbest(BigramAssocMeasures.likelihood_ratio,1000)    
    for i in range(len(a)):
        l.append(a[i][0]+' '+a[i][1])
    return l
    


def trigrams_(text, tokens):
    l=[]
     
    finder = TrigramCollocationFinder.from_words(tokens)

    a = finder.nbest(TrigramAssocMeasures.likelihood_ratio,1000)    
    for i in range(len(a)):
        l.append(a[i][0]+' '+a[i][1]+' '+a[i][2])
    
    return l

# %%
def path_selector(path):
    """ this function will return a list of all files paths with pdf format"""
    L=[]
    
    if type(path) == str and path.endswith('.pdf') == True:
        base = os.path.basename(path)
        return {'name': get_low(os.path.splitext(base)[0]), 'path': path}
    
    
    elif type(path) == str and path.endswith('.pdf') == False:
        for filename in os.listdir(path):
            if filename.endswith('.pdf'):
                base = os.path.basename(filename)
                L.append({'name': get_low(os.path.splitext(base)[0]), 'path': os.path.join(path, filename)})
    return L

# %%
from collections import Counter
def insert_text_into(path):
    List = []
    path_ = path_selector(path)
    if type(path_) == list :  
        
        for i in path_:
            text = convert_pdf_to_txt(i.get('path'))
            preproceced_text = main_PreProc(text)
            tokens = tokenizer(preproceced_text)
            bigrams = bigrams_(preproceced_text, tokens)
            trigrams = trigrams_(preproceced_text, tokens)
            counter = Counter(tokens)
            most_freq = counter.most_common(1) 
            List.append(
                         {
                          'name' : re.sub('[\d+ .pdf !"#$%&()*+,./:;<=>?@[\]^_`{|}~‘’•]','',i.get('name')),
                          'raw_text' : text,
                          'tokens' : tokens,
                          'bigrams': bigrams,
                          'trigrams': trigrams,
                          'most_common_word' : most_freq[0][0],
                          'word_freq' : most_freq[0][1]/len(tokens),
                          }
                        )
                         #'tokenized' : tokenized
                         #'bigram_text': bigrams_(main_(i.get('path'))), 
                         #'tokenized_text': tokenizer(main_(i.get('path')))
        return List
    elif type(path_) == dict : 
        text = convert_pdf_to_txt(path_.get('path'))
        preproceced_text = main_PreProc(text)
        tokens = tokenizer(preproceced_text)
        bigrams = bigrams_(preproceced_text, tokens)
        trigrams = trigrams_(preproceced_text, tokens)
        counter = Counter(tokens)
        most_freq = counter.most_common(1) 
        element = {
                          'name' : re.sub('[\d+ .pdf !"#$%&()*+,./:;<=>?@[\]^_`{|}~‘’• CV cv ]','',path_.get('name')),
                          'raw_text' : text,
                          'tokens' : tokens,
                          'bigrams': bigrams,
                          'trigrams': trigrams,
                          'most_common_word' : most_freq[0][0],
                          'word_freq' : most_freq[0][1]/len(tokens),
                  } 
        
        List.append(element)
        return element

# %%
d = insert_text_into(r'..\stage\Resume')

# %%
d
# Out:
# [{'name': 'jonas',
#   'raw_text': "   JONAS  Experience    Apr 2017 - Present  (1 year)   Sep 2015 - Mar 2017  (1 year 6 months)   Jul 2014 - Sep 2015  (1 year 2 months)   Jul 2013 - Jul 2014  (1 year)   Asc Degree   Asc Degree   Fund Accountant  Citco Fund Services (Singapore) Pte Ltd. |     Position level    Hedge fund related accounting      Financial Consultant  AXA Life Insurance Singapore Pte Ltd |     Position level    - Assisted clients to plan ahead through various financial planning models  - Provided consistent support for their insurance coverage and investment  portfolios  - Specialized in Life/General Insurance product knowledge  - Focused on needs-based selling  - Always going the extra mile to achieve high customer satisfaction level      Co-Partner & Finance Consultant  E-commerce |     Position level    - Maintained the company’s bookkeeping  - Ensured adherence to Government CPF policies and IRAS guidelines  - Adapted to different business platforms with openness to innovative ideas  - Displayed excellent customer service that would lead to long-term customer  satisfaction and continuous support  - Prompt in replies and postage handling  - Conducted periodic market research to maintain competitiveness, and  improve product quality and its user-friendliness      Credit Approval  OCBC Bank Limited |     Position level  Asc Degree  Monthly Salary  SGD 2,700    - Enhanced several project databases with self-taught Microsoft Access  (SQL, VBA & macros) knowledge  - Performed Customer Due Diligence, Know-Your-Customer and Anti-Money  Laundering checks within stipulated turnaround time (1 work day) as part of   Higher Sec   Copyright © 1996-2018, JobStreet.com. All rights reserved.   \x0cJul 2012 - Oct 2012  (3 months)   May 2010 - Jun 2011  (1 year 1 month)   Mar 2008 - Nov 2008  (8 months)         credit review process for several investment products  - Periodic portfolio reviews done to reduce Non-Performing Loan cases  - Ensured data accuracy and adherence to policies and guidelines  - Supported the department’s administrative needs such as high sensitivity  document management and secure destruction      Data Entry Officer (Part-Time during School Holida  Malayan Banking Berhad |     Position level  Asc Degree  Monthly Salary  SGD 1,600    - Keyed in crucial information of cheques into the system  - Ensured speed and absolute accuracy  - Spotted and sorted post-dated cheques separately  - Ensured daily end-of-day balancing figures tallied      Credit Officer  Malayan Banking Berhad |     Position level  Bachelor's  Monthly Salary  SGD 2,002    - Facilitated lending from bank to individuals namely in hire purchase, credit  card and overdraft applications  - Performed vigilant credit checks (CDD, KYC & AML) within stipulated  turnaround time (1-3 work days) in spite of high volume  - Periodic covenant checks and regular portfolio reviews done to reduce Non- Performing Loan cases  - Ensured data accuracy and adherence to policies and guidelines      Account Assistant  C & S Management Services    Position level  Bachelor's  Monthly Salary  SGD 1,000    - Tallied daily bank reconciliations  - Managed the restructuring of overdue and current payments with all the  creditors of clients  - Issued repayment cheques on behalf on clients on a monthly basis  - Drafted Directors' Reports & financial statements such as Cash Flow  Statement for clients          Copyright © 1996-2018, JobStreet.com. All rights reserved.   \x0cEducation    2013            2010     Skill    Advanced  Intermediate   University of London  Bachelor's    Major  Banking & Finance  Grade  Asc Degree    Modules undertaken:  Principles of Banking and Finance  Financial Intermediation  Corporate Finance  Investment Management  Valuation and Securities Analysis  Macroeconomics  Microeconomics  Management Science Methods      Temasek Polytechnic  Asc Degree    Major  Accounting & Finance     AS400, Excel, Microsoft Office, Outlook, PowerPoint  Access, ACCPAC Accounting Soft ...
#   'tokens': ['jonas',
#    'experience',
#    'apr',
#    'present',
#    'sep',
#    'mar',
#    'jul',
#    'sep',
#    'jul',
#    'jul',
#    'asc',
#    'degree',
#    'asc',
#    'degree',
#    'fund',
#    'accountt',
#    'citco',
#    'fund',
#    'services',
#    'pte',
#    'ltd',
#    'position',
#    'level',
#    'hedge',
#    'fund',
#    'related',
#    'accounting',
#    'fincial',
#    'consultt',
#    'axa',
#    'life',
#    'insurce',
#    'singapore',
#    'pte',
#    'ltd',
#    'position',
#    'level',
#    'assisted',
#    'clients',
#    'pl',
#    'ahead',
#    'fincial',
#    'plning',
#    'models',
#    'provided',
#    'consistent',
#    'support',
#    'insurce',
#    'coverage',
#    'investment',
#    'portfolios',
#    'specialized',
#    'life',
#    'general',
#    'insurce',
#    'product',
#    'knowledge',
#    'focused',
#    'needs',
#    'based',
#    'selling',
#    'going',
#    'extra',
#    'mile',
#    'achieve',
#    'high',
#    'customer',
#    'satisfaction',
#    'level',
#    'co',
#    'partner',
#    'fince',
#    'consultt',
#    'commerce',
#    'position',
#    'level',
#    'maintained',
#    'compy',
#    'bookkeeping',
#    'ensured',
#    'adherence',
#    'government',
#    'cpf',
#    'policies',
#    'iras',
#    'guidelines',
#    'adapted',
#    'different',
#    'business',
#    'platforms',
#    'openness',
#    'inative',
#    'ideas',
#    'displayed',
#    'excellent',
#    'customer',
#    'service',
#    'lead',
#    'long',
#    'term',
#    'customer',
#    'satisfaction',
#    'continuous',
#    'support',
#    'prompt',
#    'replies',
#    'postage',
#    'hdling',
#    'conducted',
#    'periodic',
#    'ket',
#    'research',
#    'ntain',
#    'competitiveness',
#    'improve',
#    'product',
#    'quality',
#    'user',
#    'friendliness',
#    'credit',
#    'approval',
#    'ocbc',
#    'bk',
#    'limited',
#    'position',
#    'level',
#    'asc',
#    'degree',
#    'monthly',
#    'salary',
#    'sgd',
#    'enhced',
#    'project',
#    'databases',
#    'self',
#    'tht',
#    'microsoft',
#    'access',
#    'sql',
#    'vba',
#    'macros',
#    'knowledge',
#    'performed',
#    'customer',
#    'diligence',
#    'know',
#    'customer',
#    'anti',
#    'money',
#    'laundering',
#    'checks',
#    'stipulated',
#    'turnaround',
#    'time',
#    'higher',
#    'sec',
#    'copyright',
#    'jobstreet',
#    'com',
#    'rights',
#    'reserved',
#    'jul',
#    'oct',
#    'jun',
#    'credit',
#    'review',
#    'process',
#    'investment',
#    'products',
#    'periodic',
#    'portfolio',
#    'reviews',
#    'reduce',
#    'non',
#    'performing',
#    'lo',
#    'cases',
#    'ensured',
#    'data',
#    'accuracy',
#    'adherence',
#    'policies',
#    'guidelines',
#    'supported',
#    'department',
#    'administrative',
#    'needs',
#    'high',
#    'sensitivity',
#    'document',
#    'magement',
#    'secure',
#    'destruction',
#    'data',
#    'entry',
#    'officer',
#    'time',
#    'school',
#    'holida',
#    'malay',
#    'bking',
#    'berhad',
#    'position',
#    'level',
#    'asc',
#    'degree',
#    'monthly',
#    'salary',
#    'sgd',
#    'keyed',
#    'crucial',
#    'information',
#    'cheques',
#    'system',
#    'ensured',
#    'speed',
#    'absolute',
#    'accuracy',
#    'spotted',
#    'sorted',
#    'post',
#    'dated',
#    'cheques',
#    'arately',
#    'ensured',
#    'daily',
#    'end',
#    'balcing',
#    'figures',
#    'tallied',
#    'credit',
#    'officer',
#    'malay',
#    'bking',
#    'berhad',
#    'position',
#    'level',
#    'bachelor',
#    'salary',
#    'sgd',
#    'facilitated',
#    'lending',
#    'bk',
#    'individuals',
#    'hire',
#    'purchase',
#    'credit',
#    'card',
#    'overdraft',
#    'applications',
#    'performed',
#    'vigilt',
#    'credit',
#    'checks',
#    'cdd',
#    'kyc',
#    'aml',
#    'stipulated',
#    'turnaround',
#    'time',
#    'work',
#    'days',
#    'spite',
#    'high',
#    'volume',
#    'periodic',
#    'covent',
#    'checks',
#    'regular',
#    'portfolio',
#    'reviews',
#    'reduce',
#    'non',
#    'performing',
#    'lo',
#    'cases',
#    'ensured',
#    'data',
#    'accuracy',
#    'adherence',
#    'policies',
#    'guidelines',
#    'account',
#    'assistt',
#    'magement',
#    'services',
#    'position',
#    'level',
#    'bachelor',
#    'salary',
#    'sgd',
#    'tallied',
#    'bk',
#    'reconciliations',
#    'maged',
#    'restructuring',
#    'overdue',
#    'current',
#    'payments',
#    'creditors',
#    'clients',
#    'issued',
#    'repayment',
#    'cheques',
#    'behalf',
#    'clients',
#    'basis',
#    'drafted',
#    'directors',
#    'reports',
#    'fincial',
#    'statements',
#    'cash',
#    'flow',
#    'statement',
#    'clients',
#    'copyright',
#    'jobstreet',
#    'com',
#    'rights',
#    'reserved',
#    'education',
#    'skill',
#    'advced',
#    'intermediate',
#    'university',
#    'bachelor',
#    'major',
#    'bking',
#    'fince',
#    'grade',
#    'asc',
#    'degree',
#    'modules',
#    'undertaken',
#    'principles',
#    'bking',
#    'fince',
#    'fincial',
#    'intermediation',
#    'corporate',
#    'fince',
#    'investment',
#    'magement',
#    'valuation',
#    'securities',
#    'analysis',
#    'macroeconomics',
#    'microeconomics',
#    'magement',
#    'science',
#    'methods',
#    'temasek',
#    'polytechnic',
#    'asc',
#    'degree',
#    'major',
#    'accounting',
#    'fince',
#    'excel',
#    'microsoft',
#    'office',
#    'outlook',
#    'powerpoint',
#    'access',
#    'accpac',
#    'accounting',
#    'software',
#    'ubs',
#    'accounting',
#    'software',
#    'lguages',
#    'proficiency',
#    'level',
#    'poor',
#    'excellent',
#    'lguage',
#    'secondary',
#    'sch',
#    'lguage',
#    'jobstreet',
#    'english',
#    'lguage',
#    'assessment',
#    'jela',
#    'date',
#    'taken',
#    'score',
#    'additional',
#    'info',
#    'spoken',
#    'written',
#    'relevt',
#    'certificates',
#    'copyright',
#    'jobstreet',
#    'com',
#    'rights',
#    'reserved',
#    'sgd',
#    'expected',
#    'salary',
#    'information',
#    'resourceful',
#    'professional',
#    'equipped',
#    'knowledge',
#    'accounting',
#    'fince',
#    'adaptable',
#    'fast',
#    'learner',
#    'comprehend',
#    'complex',
#    'skills',
#    'required',
#    'job',
#    'solution',
#    'focused',
#    'perspective',
#    'remembers',
#    'importce',
#    'root',
#    'cause',
#    'alysis',
#    'detail',
#    'oriented',
#    'personality',
#    'motivated',
#    'produce',
#    'work',
#    'excellence',
#    'constt',
#    'lookout',
#    'improvements',
#    'strong',
#    'alytical',
#    'skills',
#    'aptitude',
#    'numbers',
#    'task',
#    'nature',
#    'induces',
#    'persistence',
#    'determination',
#    'commitment',
#    'till',
#    'job',
#    'completion',
#    'customer',
#    'centric',
#    'mindset',
#    'going',
#    'extra',
#    'mile',
#    'ensure',
#    'positive',
#    'customer',
#    'experience',
#    'gender',
#    'address',
#    'female',
#    'singapore',
#    'copyright',
#    'jobstreet',
#    'com',
#    'rights',
#    'reserved'],
#   'bigrams': ['asc degree',
#    'position level',
#    'com rights',
#    'rights reserved',
#    'copyright jobstreet',
#    'jobstreet com',
#    'salary sgd',
#    'extra mile',
#    'going extra',
#    'lo cases',
#    'non performing',
#    'performing lo',
#    'portfolio reviews',
#    'pte ltd',
#    'reduce non',
#    'reviews reduce',
#    'stipulated turnaround',
#    'turnaround time',
#    'bking berhad',
#    'malay bking',
#    'accounting software',
#    'cases ensured',
#    'monthly salary',
#    'accuracy adherence',
#    'adherence policies',
#    'data accuracy',
#    'policies guidelines',
#    'degree monthly',
#    'berhad position',
#    'customer satisfaction',
#    'ltd position',
#    'ensured data',
#    'bachelor salary',
#    'account assistt',
#    'accountt citco',
#    'adaptable fast',
#    'adapted different',
#    'additional info',
#    'address female',
#    'advced intermediate',
#    'alysis detail',
#    'analysis macroeconomics',
#    'anti money',
#    'approval ocbc',
#    'apr present',
#    'aptitude numbers',
#    'assessment jela',
#    'balcing figures',
#    'based selling',
#    'basis drafted',
#    'business platforms',
#    'card overdraft',
#    'cash flow',
#    'cause alysis',
#    'cdd kyc',
#    'centric mindset',
#    'co partner',
#    'commitment till',
#    'competitiveness improve',
#    'comprehend complex',
#    'compy bookkeeping',
#    'constt lookout',
#    'current payments',
#    'daily end',
#    'databases self',
#    'date taken',
#    'days spite',
#    'department administrative',
#    'detail oriented',
#    'determination commitment',
#    'different business',
#    'diligence know',
#    'directors reports',
#    'drafted directors',
#    'education skill',
#    'end balcing',
#    'enhced project',
#    'ensure positive',
#    'excellence constt',
#    'facilitated lending',
#    'fast learner',
#    'flow statement',
#    'gender address',
#    'government cpf',
#    'hdling conducted',
#    'higher sec',
#    'hire purchase',
#    'ideas displayed',
#    'importce root',
#    'improvements strong',
#    'inative ideas',
#    'individuals hire',
#    'induces persistence',
#    'info spoken',
#    'intermediate university',
#    'intermediation corporate',
#    'issued repayment',
#    'jela date',
#    'ket research',
#    'keyed crucial',
#    'kyc aml',
#    'lead long',
#    'learner comprehend',
#    'lguages proficiency',
#    'long term',
#    'lookout improvements',
#    'macroeconomics microeconomics',
#    'maged restructuring',
#    'maintained compy',
#    'methods temasek',
#    'models provided',
#    'modules undertaken',
#    'money laundering',
#    'motivated produce',
#    'nature induces',
#    'ntain competitiveness',
#    'numbers task',
#    'oct jun',
#    'office outlook',
#    'openness inative',
#    'oriented personality',
#    'outlook powerpoint',
#    'overdraft applications',
#    'overdue current',
#    'payments creditors',
#    'persistence determination',
#    'personality motivated',
#    'perspective remembers',
#    'pl ahead',
#    'platforms openness',
#    'plning models',
#    'portfolios specialized',
#    'post dated',
#    'postage hdling',
#    'professional equipped',
#    'project databases',
#    'prompt replies',
#    'provided consistent',
#    'quality user',
#    'reconciliations maged',
#    'relevt certificates',
#    'remembers importce',
#    'replies postage',
#    'research ntain',
#    'resourceful professional',
#    'restructuring overdue',
#    'review process',
#    'root cause',
#    'school holida',
#    'science methods',
#    'score additional',
#    'secondary sch',
#    'secure destruction',
#    'securities analysis',
#    'self tht',
#    'sensitivity document',
#    'service lead',
#    'skill advced',
#    'sorted post',
#    'speed absolute',
#    'spoken written',
#    'spotted sorted',
#    'sql vba',
#    'statements cash',
#    'strong alytical',
#    'supported department',
#    'taken score',
#    'task nature',
#    'temasek polytechnic',
#    'undertaken principles',
#    'user friendliness',
#    'valuation securities',
#    'vba macros',
#    'written relevt',
#    'bking fince',
#    'level bachelor',
#    'access accpac',
#    'access sql',
#    'administrative needs',
#    'alytical skills',
#    'aml stipulated',
#    'applications performed',
#    'axa life',
#    'complex skills',
#    'consistent support',
#    'consultt axa',
#    'consultt commerce',
#    'continuous support',
#    'crucial information',
#    'displayed excellent',
#    'entry officer',
#    'excel microsoft',
#    'experience apr',
#    'experience gender',
#    'female singapore',
#    'figures tallied',
#    'focused perspective',
#    'holida malay',
#    'improve product',
#    'information resourceful',
#    'job completion',
#    'job solution',
#    'jonas experience',
#    'life general',
#    'microsoft office',
#    'mile achieve',
#    'mile ensure',
#    'mindset going',
#    'needs based',
#    'performed vigilt',
#    'poor excellent',
#    'powerpoint access',
#    'present sep',
#    'produce work',
#    'product quality',
#    'regular portfolio',
#    'required job',
#    'satisfaction continuous',
#    'selling going',
#    'sep mar',
#    'skills aptitude',
#    'skills required',
#    'software lguages',
#    'software ubs',
#    'solution focused',
#    'specialized life',
#    'support prompt',
#    'tht microsoft',
#    'till job',
#    'work days',
#    'work excellence',
#    'accounting fince',
#    'absolute accuracy',
#    'accuracy spotted',
#    'achieve high',
#    'adherence government',
#    'bk individuals',
#    'bk limited',
#    'bk reconciliations',
#    'checks cdd',
#    'checks regular',
#    'cheques arately',
#    'cheques behalf',
#    'cheques system',
#    'citco fund',
#    'conducted periodic',
#    'covent checks',
#    'coverage investment',
#    'cpf policies',
#    'data entry',
#    'dated cheques',
#    'destruction data',
#    'english lguage',
#    'equipped knowledge',
#    'fund accountt',
#    'fund related',
#    'general insurce',
#    'guidelines account',
#    'guidelines adapted',
#    'guidelines supported',
#    'hedge fund',
#    'high sensitivity',
#    'high volume',
#    'insurce coverage',
#    'investment portfolios',
#    'investment products',
#    'iras guidelines',
#    'laundering checks',
#    'lending bk',
#    'lguage assessment',
#    'lguage secondary',
#    'macros knowledge',
#    'ocbc bk',
#    'periodic covent',
#    'periodic ket',
#    'policies iras',
#    'process investment',
#    'products periodic',
#    'repayment cheques',
#    'sch lguage',
#    'spite high',
#    'time higher',
#    'time school',
#    'university bachelor',
#    'volume periodic',
#    'ahead fincial',
#    'assisted clients',
#    'assistt magement',
#    'behalf clients',
#    'certificates copyright',
#    'clients basis',
#    'clients issued',
#    'clients pl',
#    'creditors clients',
#    'document magement',
#    'fincial intermediation',
#    'fincial plning',
#    'fincial statements',
#    'jul oct',
#    'magement science',
#    'magement secure',
#    'magement valuation',
#    'mar jul',
#    'microeconomics magement',
#    'principles bking',
#    'reports fincial',
#    'reserved education',
#    'sec copyright',
#    'statement clients',
#    'accpac accounting',
#    'arately ensured',
#    'bookkeeping ensured',
#    'credit approval',
#    'credit card',
#    'credit review',
#    'ensured daily',
#    'ensured speed',
#    'expected salary',
#    'friendliness credit',
#    'jobstreet english',
#    'jun credit',
#    'purchase credit',
#    'related accounting',
#    'sgd enhced',
#    'sgd expected',
#    'sgd facilitated',
#    'sgd keyed',
#    'system ensured',
#    'ubs accounting',
#    'vigilt credit',
#    'corporate fince',
#    'degree modules',
#    'fince adaptable',
#    'fince excel',
#    'fince grade',
#    'grade asc',
#    'partner fince',
#    'polytechnic asc',
#    'level asc',
#    'focused needs',
#    'microsoft access',
#    'officer malay',
#    'services pte',
#    'singapore pte',
#    'commerce position',
#    'completion customer',
#    'customer anti',
#    'customer centric',
#    'customer diligence',
#    'customer service',
#    'know customer',
#    'limited position',
#    'positive customer',
#    'term customer',
#    'level assisted',
#    'level co',
#    'level hedge',
#    'level maintained',
#    'level poor',
#    'proficiency level',
#    'bachelor major',
#    'checks stipulated',
#    'excellent lguage',
#    'fund services',
#    'information cheques',
#    'insurce product',
#    'insurce singapore',
#    'knowledge focused',
#    'knowledge performed',
#    'life insurce',
#    'needs high',
#    'officer time',
#    'periodic portfolio',
#    'product knowledge',
#    'support insurce',
#    'tallied bk',
#    'time work',
#    'fincial consultt',
#    'jul sep',
#    'magement services',
#    'major bking',
#    'sep jul',
#    'singapore copyright',
#    'credit officer',
#    'major accounting',
#    'salary information',
#    'sgd tallied',
#    'tallied credit',
#    'degree major',
#    'fince consultt',
#    'investment magement',
#    'customer experience',
#    'excellent customer',
#    'performed customer',
#    'services position',
#    'credit checks',
#    'ensured adherence',
#    'knowledge accounting',
#    'lguage jobstreet',
#    'clients copyright',
#    'jul jul',
#    'reserved jul',
#    'satisfaction level',
#    'degree fund',
#    'fince investment',
#    'accounting fincial',
#    'reserved sgd',
#    'high customer',
#    'fince fincial',
#    'jul asc',
#    'degree asc'],
#   'trigrams': ['com rights reserved',
#    'copyright jobstreet com',
#    'jobstreet com rights',
#    'asc degree monthly',
#    'berhad position level',
#    'ltd position level',
#    'position level bachelor',
#    'position level asc',
#    'asc degree modules',
#    'grade asc degree',
#    'polytechnic asc degree',
#    'level asc degree',
#    'commerce position level',
#    'limited position level',
#    'position level assisted',
#    'position level hedge',
#    'position level maintained',
#    'asc degree major',
#    'asc degree fund',
#    'services position level',
#    'jul asc degree',
#    'asc degree asc',
#    'degree asc degree',
#    'monthly salary sgd',
#    'rights reserved education',
#    'bachelor salary sgd',
#    'going extra mile',
#    'non performing lo',
#    'performing lo cases',
#    'portfolio reviews reduce',
#    'reduce non performing',
#    'reviews reduce non',
#    'rights reserved jul',
#    'rights reserved sgd',
#    'certificates copyright jobstreet',
#    'sec copyright jobstreet',
#    'singapore copyright jobstreet',
#    'stipulated turnaround time',
#    'clients copyright jobstreet',
#    'malay bking berhad',
#    'salary sgd enhced',
#    'salary sgd facilitated',
#    'salary sgd keyed',
#    'lo cases ensured',
#    'pte ltd position',
#    'salary sgd tallied',
#    'cases ensured data',
#    'accuracy adherence policies',
#    'adherence policies guidelines',
#    'data accuracy adherence',
#    'bking berhad position',
#    'aml stipulated turnaround',
#    'extra mile achieve',
#    'extra mile ensure',
#    'mindset going extra',
#    'regular portfolio reviews',
#    'selling going extra',
#    'degree monthly salary',
#    'ensured data accuracy',
#    'services pte ltd',
#    'singapore pte ltd',
#    'checks stipulated turnaround',
#    'periodic portfolio reviews',
#    'turnaround time higher',
#    'holida malay bking',
#    'sep mar jul',
#    'level bachelor salary',
#    'major bking fince',
#    'turnaround time work',
#    'accounting software lguages',
#    'accounting software ubs',
#    'accpac accounting software',
#    'ubs accounting software',
#    'major accounting fince',
#    'policies guidelines account',
#    'policies guidelines supported',
#    'officer malay bking',
#    'customer satisfaction continuous',
#    'term customer satisfaction',
#    'adaptable fast learner',
#    'adapted different business',
#    'additional info spoken',
#    'advced intermediate university',
#    'alysis detail oriented',
#    'analysis macroeconomics microeconomics',
#    'anti money laundering',
#    'aptitude numbers task',
#    'assessment jela date',
#    'basis drafted directors',
#    'business platforms openness',
#    'card overdraft applications',
#    'cash flow statement',
#    'cause alysis detail',
#    'cdd kyc aml',
#    'constt lookout improvements',
#    'current payments creditors',
#    'daily end balcing',
#    'databases self tht',
#    'date taken score',
#    'detail oriented personality',
#    'determination commitment till',
#    'different business platforms',
#    'drafted directors reports',
#    'education skill advced',
#    'end balcing figures',
#    'enhced project databases',
#    'excellence constt lookout',
#    'fast learner comprehend',
#    'gender address female',
#    'importce root cause',
#    'improvements strong alytical',
#    'inative ideas displayed',
#    'individuals hire purchase',
#    'induces persistence determination',
#    'info spoken written',
#    'jela date taken',
#    'ket research ntain',
#    'lead long term',
#    'learner comprehend complex',
#    'lookout improvements strong',
#    'maged restructuring overdue',
#    'maintained compy bookkeeping',
#    'methods temasek polytechnic',
#    'models provided consistent',
#    'modules undertaken principles',
#    'nature induces persistence',
#    'ntain competitiveness improve',
#    'numbers task nature',
#    'office outlook powerpoint',
#    'openness inative ideas',
#    'oriented personality motivated',
#    'overdue current payments',
#    'persistence determination commitment',
#    'personality motivated produce',
#    'perspective remembers importce',
#    'platforms openness inative',
#    'plning models provided',
#    'postage hdling conducted',
#    'project databases self',
#    'prompt replies postage',
#    'quality user friendliness',
#    'reconciliations maged restructuring',
#    'remembers importce root',
#    'replies postage hdling',
#    'research ntain competitiveness',
#    'resourceful professional equipped',
#    'restructuring overdue current',
#    'root cause alysis',
#    'science methods temasek',
#    'score additional info',
#    'securities analysis macroeconomics',
#    'service lead long',
#    'skill advced intermediate',
#    'sorted post dated',
#    'spoken written relevt',
#    'spotted sorted post',
#    'sql vba macros',
#    'statements cash flow',
#    'supported department administrative',
#    'taken score additional',
#    'task nature induces',
#    'valuation securities analysis',
#    'written relevt certificates',
#    'sep jul jul',
#    'cheques arately ensured',
#    'cheques system ensured',
#    'access sql vba',
#    'address female singapore',
#    'alytical skills aptitude',
#    'applications performed vigilt',
#    'apr present sep',
#    'balcing figures tallied',
#    'based selling going',
#    'centric mindset going',
#    'commitment till job',
#    'competitiveness improve product',
#    'complex skills required',
#    'comprehend complex skills',
#    'continuous support prompt',
#    'department administrative needs',
#    'excel microsoft office',
#    'experience apr present',
#    'experience gender address',
#    'focused perspective remembers',
#    'ideas displayed excellent',
#    'improve product quality',
#    'information resourceful professional',
#    'jonas experience apr',
#    'keyed crucial information',
#    'kyc aml stipulated',
#    'microsoft office outlook',
#    'mile ensure positive',
#    'motivated produce work',
#    'needs based selling',
#    'outlook powerpoint access',
#    'overdraft applications performed',
#    'portfolios specialized life',
#    'powerpoint access accpac',
#    'present sep mar',
#    'produce work excellence',
#    'product quality user',
#    'provided consistent support',
#    'required job solution',
#    'school holida malay',
#    'self tht microsoft',
#    'skills aptitude numbers',
#    'software lguages proficiency',
#    'solution focused perspective',
#    'specialized life general',
#    'strong alytical skills',
#    'support prompt replies',
#    'till job completion',
#    'work days spite',
#    'work excellence constt',
#    'high customer satisfaction',
#    'absolute accuracy spotted',
#    'accountt citco fund',
#    'accuracy spotted sorted',
#    'adherence government cpf',
#    'approval ocbc bk',
#    'bk individuals hire',
#    'bk reconciliations maged',
#    'checks cdd kyc',
#    'conducted periodic ket',
#    'covent checks regular',
#    'coverage investment portfolios',
#    'cpf policies iras',
#    'dated cheques arately',
#    'days spite high',
#    'destruction data entry',
#    'english lguage assessment',
#    'facilitated lending bk',
#    'fund accountt citco',
#    'government cpf policies',
#    'guidelines account assistt',
#    'guidelines adapted different',
#    'guidelines supported department',
#    'hdling conducted periodic',
#    'hedge fund related',
#    'high sensitivity document',
#    'intermediate university bachelor',
#    'investment portfolios specialized',
#    'iras guidelines adapted',
#    'issued repayment cheques',
#    'lending bk individuals',
#    'lguage assessment jela',
#    'lguage secondary sch',
#    'money laundering checks',
#    'ocbc bk limited',
#    'periodic ket research',
#    'post dated cheques',
#    'process investment products',
#    'professional equipped knowledge',
#    'repayment cheques behalf',
#    'review process investment',
#    'secondary sch lguage',
#    'secure destruction data',
#    'speed absolute accuracy',
#    'spite high volume',
#    'time higher sec',
#    'time school holida',
#    'vba macros knowledge',
#    'volume periodic covent',
#    'bking fince grade',
#    'principles bking fince',
#    'account assistt magement',
#    'ahead fincial plning',
#    'assisted clients pl',
#    'behalf clients basis',
#    'clients basis drafted',
#    'clients issued repayment',
#    'clients pl ahead',
#    'creditors clients issued',
#    'directors reports fincial',
#    'document magement secure',
#    'fincial intermediation corporate',
#    'fincial plning models',
#    'fincial statements cash',
#    'flow statement clients',
#    'higher sec copyright',
#    'jul oct jun',
#    'macroeconomics microeconomics magement',
#    'magement science methods',
#    'magement secure destruction',
#    'magement valuation securities',
#    'microeconomics magement science',
#    'payments creditors clients',
#    'pl ahead fincial',
#    'relevt certificates copyright',
#    'reports fincial statements',
#    'reserved education skill',
#    'sensitivity document magement',
#    'undertaken principles bking',
#    'arately ensured daily',
#    'compy bookkeeping ensured',
#    'credit approval ocbc',
#    'credit card overdraft',
#    'credit review process',
#    'ensured daily end',
#    'ensured speed absolute',
#    'friendliness credit approval',
#    'hire purchase credit',
#    'jun credit review',
#    'oct jun credit',
#    'purchase credit card',
#    'sgd enhced project',
#    'sgd facilitated lending',
#    'sgd keyed crucial',
#    'system ensured speed',
#    'user friendliness credit',
#    'co partner fince',
#    'degree modules undertaken',
#    'fince adaptable fast',
#    'intermediation corporate fince',
#    'temasek polytechnic asc',
#    'consultt axa life',
#    'focused needs based',
#    'job solution focused',
#    'microsoft access sql',
#    'satisfaction continuous support',
#    'skills required job',
#    'tht microsoft access',
#    'accounting fince adaptable',
#    'accounting fince excel',
#    'customer satisfaction level',
#    'completion customer centric',
#    'customer anti money',
#    'customer centric mindset',
#    'customer diligence know',
#    'customer service lead',
#    'diligence know customer',
#    'ensure positive customer',
#    'know customer anti',
#    'long term customer',
#    'level co partner',
#    'level maintained compy',
#    'lguages proficiency level',
#    'proficiency level poor',
#    'administrative needs high',
#    'axa life insurce',
#    'checks regular portfolio',
#    'citco fund services',
#    'consistent support insurce',
#    'crucial information cheques',
#    'data entry officer',
#    'entry officer time',
#    'excellent lguage secondary',
#    'general insurce product',
#    'information cheques system',
#    'laundering checks stipulated',
#    'life general insurce',
#    'macros knowledge performed',
#    'mile achieve high',
#    'needs high sensitivity',
#    'officer time school',
#    'poor excellent lguage',
#    'products periodic portfolio',
#    'support insurce coverage',
#    'tallied bk reconciliations',
#    'time work days',
#    'university bachelor major',
#    'assistt magement services',
#    'female singapore copyright',
#    'fincial consultt axa',
#    'mar jul sep',
#    'high volume periodic',
#    'insurce coverage investment',
#    'investment products periodic',
#    'periodic covent checks',
#    'policies iras guidelines',
#    'access accpac accounting',
#    'expected salary information',
#    'figures tallied credit',
#    'performed vigilt credit',
#    'salary information resourceful',
#    'software ubs accounting',
#    'fince consultt commerce',
#    'fince excel microsoft',
#    'partner fince consultt',
#    'cheques behalf clients',
#    'investment magement valuation',
#    'consultt commerce position',
#    'customer experience gender',
#    'displayed excellent customer',
#    'excellent customer service',
#    'job completion customer',
#    'performed customer diligence',
#    'positive customer experience',
#    'bookkeeping ensured adherence',
#    'credit checks cdd',
#    'ensured adherence government',
#    'equipped knowledge accounting',
#    'fund related accounting',
#    'jobstreet english lguage',
#    'lguage jobstreet english',
#    'sch lguage jobstreet',
#    'vigilt credit checks',
#    'bking fince fincial',
#    'reserved jul oct',
#    'statement clients copyright',
#    'level poor excellent',
#    'satisfaction level co',
#    'corporate fince investment',
#    'degree fund accountt',
#    'knowledge accounting fince',
#    'fund services pte',
#    'insurce singapore pte',
#    'knowledge focused needs',
#    'life insurce singapore',
#    'product knowledge focused',
#    'related accounting fincial',
#    'reserved sgd expected',
#    'achieve high customer',
#    'bk limited position',
#    'fince fincial intermediation',
#    'sgd expected salary',
#    'level hedge fund',
#    'insurce product knowledge',
#    'credit officer malay',
#    'tallied credit officer',
#    'level assisted clients',
#    'fince grade asc',
#    'bachelor major bking',
#    'sgd tallied bk',
#    'jul sep jul',
#    'accounting fincial consultt',
#    'knowledge performed customer',
#    'magement services position',
#    'degree major accounting',
#    'fince investment magement',
#    'jul jul asc'],
#   'most_common_word': 'level',
#   'word_freq': 0.019230769230769232},
#  {'name': 'amy',
#   'raw_text': 'AMY      PROFILE   Fund  accountant  with  nearly  2  years  of  experience  in  hedge  fund  administration,  which  includes  preparation  of  NAV  calculations,  financial  statements  and  associated  reports.  Consistently  meeting  deadlines while ensuring a high quality of work standards. Fast learner, driven for results and analytical  in problem solving.   WORK EXPERIENCE   Citco Fund Services (Singapore) Pte Ltd                            Accountant   Jan 2016 – Present Fund   •  Calculation of estimate and final NAVs on a daily, weekly and monthly basis  •  Preparation of cash and position reconciliation reports  •  Daily pre-production tasks such as price checks, interest accruals and fees booking  •  Maintaining day-to-day relationships with investment managers, brokers and auditors  •  Communicating with the reconciliations team to ensure consistent and high-quality standards   when delivering NAV packages   •  Undertaking fund migrations from Citco Toronto and Citco Dublin Office  •  Familiar  with  various  pricing  valuation  models  e.g.  Independent  Price  Verification,  External   Valuer  Investigation and resolution of breaks   •  •  Training of new fund accountants in the team  •  Assist in reviewing estimate and final NAV packs   Norgas Carriers Private Limited                                             Accountant   Nov 2014 – Apr 2015   •  Processing invoices from suppliers and scheduling payment remittances  •  Assisted in collecting outstanding debts from debtors  •  •  •  Monthly bank reconciliation  •  Perform intercompany journal entries and reconciliation   Involved in the year end closing of accounts  Liaised with external auditors during interim and final audit   Singapore Armed Forces                                                  Specialist/ NSF Battery Sergeant Major (2nd Sergeant, 24th Battalion Singapore Artillery)    Jul  2013  –  July  2014  Operation   •   In charge  of the training management and  administration matters, ensuring smooth running  and operation of the battalion   •  Responsible for the welfare, discipline and regimentation of 60 fellow NSFs  •  Rallied with superiors to keep a lookout for troubled soldiers, acted as the first level of feedback   for peers   \x0cEDUCATION AND QUALIFICATIONS   Royal Melbourne Institute of Technology (RMIT)  Bachelor of Business (Accountancy)  GPA: 3.1 / 4   Temasek Polytechnic  Diploma in Accounting and Finance   Ngee Ann Secondary School  GCE ‘O’ Levels Certificate        SKILLS AND COMPETENCIES   Jul 2014 –   Oct 2015   Apr 2009 – Apr 2012               Jan 2005 – Nov 2008   •  Trained in accounting softwares, Aexeo, Agresso Business World, Sage AccPac and MYOB  •  Proficient in Microsoft Excel, PowerPoint and Word  •  Competent in Financial and Economic Databases (Bloomberg, Thomson Reuters)  •  •   Languages spoken: English, Chinese, Cantonese  Languages written: English, Chinese   \x0c',
#   'tokens': ['amy',
#    'profile',
#    'fund',
#    'accountt',
#    'nearly',
#    'experience',
#    'hedge',
#    'fund',
#    'administration',
#    'includes',
#    'preparation',
#    'nav',
#    'calculations',
#    'fincial',
#    'statements',
#    'associated',
#    'reports',
#    'consistently',
#    'meeting',
#    'deadlines',
#    'ensuring',
#    'high',
#    'quality',
#    'work',
#    'stdards',
#    'fast',
#    'learner',
#    'driven',
#    'results',
#    'alytical',
#    'problem',
#    'solving',
#    'work',
#    'experience',
#    'citco',
#    'fund',
#    'services',
#    'pte',
#    'ltd',
#    'accountt',
#    'present',
#    'fund',
#    'calculation',
#    'estimate',
#    'final',
#    'navs',
#    'basis',
#    'preparation',
#    'cash',
#    'position',
#    'reconciliation',
#    'reports',
#    'daily',
#    'pre',
#    'production',
#    'tasks',
#    'price',
#    'checks',
#    'interest',
#    'accruals',
#    'fees',
#    'booking',
#    'maintaining',
#    'day',
#    'day',
#    'relationships',
#    'investment',
#    'magers',
#    'brokers',
#    'auditors',
#    'communicating',
#    'reconciliations',
#    'team',
#    'ensure',
#    'consistent',
#    'high',
#    'quality',
#    'stdards',
#    'delivering',
#    'nav',
#    'packages',
#    'undertaking',
#    'fund',
#    'migrations',
#    'citco',
#    'toronto',
#    'citco',
#    'dublin',
#    'office',
#    'familiar',
#    'pricing',
#    'valuation',
#    'models',
#    'independent',
#    'price',
#    'verification',
#    'external',
#    'valuer',
#    'investigation',
#    'resolution',
#    'breaks',
#    'training',
#    'new',
#    'fund',
#    'accountts',
#    'team',
#    'assist',
#    'reviewing',
#    'estimate',
#    'final',
#    'nav',
#    'packs',
#    'norgas',
#    'carriers',
#    'private',
#    'limited',
#    'accountt',
#    'processing',
#    'invoices',
#    'suppliers',
#    'scheduling',
#    'payment',
#    'remittces',
#    'assisted',
#    'collecting',
#    'outstding',
#    'debts',
#    'debtors',
#    'bk',
#    'reconciliation',
#    'perform',
#    'intercompy',
#    'journal',
#    'entries',
#    'reconciliation',
#    'involved',
#    'closing',
#    'accounts',
#    'liaised',
#    'external',
#    'auditors',
#    'interim',
#    'final',
#    'audit',
#    'singapore',
#    'armed',
#    'forces',
#    'specialist',
#    'nsf',
#    'battery',
#    'serget',
#    'major',
#    'serget',
#    'battalion',
#    'singapore',
#    'artillery',
#    'jul',
#    'operation',
#    'charge',
#    'training',
#    'magement',
#    'administration',
#    'matters',
#    'ensuring',
#    'smooth',
#    'running',
#    'operation',
#    'battalion',
#    'responsible',
#    'welfare',
#    'discipline',
#    'regimentation',
#    'fellow',
#    'nsfs',
#    'rallied',
#    'superiors',
#    'lookout',
#    'troubled',
#    'soldiers',
#    'acted',
#    'level',
#    'feedback',
#    'peers',
#    'education',
#    'qualifications',
#    'royal',
#    'melbourne',
#    'institute',
#    'technology',
#    'rmit',
#    'bachelor',
#    'business',
#    'accountcy',
#    'gpa',
#    'temasek',
#    'polytechnic',
#    'diploma',
#    'accounting',
#    'fince',
#    'ngee',
#    'ann',
#    'secondary',
#    'school',
#    'levels',
#    'certificate',
#    'skills',
#    'competencies',
#    'jul',
#    'trained',
#    'accounting',
#    'softwares',
#    'aexeo',
#    'agresso',
#    'business',
#    'world',
#    'sage',
#    'accpac',
#    'myob',
#    'proficient',
#    'microsoft',
#    'excel',
#    'powerpoint',
#    'word',
#    'competent',
#    'fincial',
#    'economic',
#    'databases',
#    'thomson',
#    'reuters',
#    'lguages',
#    'spoken',
#    'english',
#    'chinese',
#    'ctonese',
#    'lguages',
#    'written',
#    'english',
#    'chinese'],
#   'bigrams': ['english chinese',
#    'high quality',
#    'estimate final',
#    'accountcy gpa',
#    'accounts liaised',
#    'accpac myob',
#    'accruals fees',
#    'acted level',
#    'aexeo agresso',
#    'alytical problem',
#    'amy profile',
#    'ann secondary',
#    'armed forces',
#    'assist reviewing',
#    'assisted collecting',
#    'booking maintaining',
#    'carriers private',
#    'cash position',
#    'certificate skills',
#    'checks interest',
#    'closing accounts',
#    'collecting outstding',
#    'communicating reconciliations',
#    'consistently meeting',
#    'daily pre',
#    'databases thomson',
#    'debtors bk',
#    'debts debtors',
#    'discipline regimentation',
#    'driven results',
#    'dublin office',
#    'economic databases',
#    'education qualifications',
#    'ensure consistent',
#    'excel powerpoint',
#    'familiar pricing',
#    'fast learner',
#    'feedback peers',
#    'fees booking',
#    'fellow nsfs',
#    'fince ngee',
#    'forces specialist',
#    'gpa temasek',
#    'institute technology',
#    'intercompy journal',
#    'interest accruals',
#    'investigation resolution',
#    'investment magers',
#    'invoices suppliers',
#    'involved closing',
#    'journal entries',
#    'learner driven',
#    'level feedback',
#    'levels certificate',
#    'lookout troubled',
#    'magers brokers',
#    'meeting deadlines',
#    'melbourne institute',
#    'microsoft excel',
#    'models independent',
#    'myob proficient',
#    'navs basis',
#    'ngee ann',
#    'norgas carriers',
#    'nsf battery',
#    'nsfs rallied',
#    'office familiar',
#    'outstding debts',
#    'packages undertaking',
#    'packs norgas',
#    'payment remittces',
#    'peers education',
#    'perform intercompy',
#    'polytechnic diploma',
#    'powerpoint word',
#    'pre production',
#    'pricing valuation',
#    'private limited',
#    'problem solving',
#    'processing invoices',
#    'production tasks',
#    'proficient microsoft',
#    'pte ltd',
#    'qualifications royal',
#    'rallied superiors',
#    'regimentation fellow',
#    'relationships investment',
#    'remittces assisted',
#    'resolution breaks',
#    'responsible welfare',
#    'results alytical',
#    'rmit bachelor',
#    'royal melbourne',
#    'sage accpac',
#    'scheduling payment',
#    'school levels',
#    'secondary school',
#    'services pte',
#    'skills competencies',
#    'smooth running',
#    'softwares aexeo',
#    'soldiers acted',
#    'specialist nsf',
#    'statements associated',
#    'superiors lookout',
#    'suppliers scheduling',
#    'technology rmit',
#    'temasek polytechnic',
#    'thomson reuters',
#    'troubled soldiers',
#    'valuation models',
#    'valuer investigation',
#    'welfare discipline',
#    'word competent',
#    'world sage',
#    'accounting fince',
#    'accounting softwares',
#    'accountts team',
#    'administration includes',
#    'administration matters',
#    'agresso business',
#    'artillery jul',
#    'associated reports',
#    'audit singapore',
#    'auditors communicating',
#    'auditors interim',
#    'bachelor business',
#    'basis preparation',
#    'battalion responsible',
#    'battery serget',
#    'breaks training',
#    'brokers auditors',
#    'business accountcy',
#    'business world',
#    'calculation estimate',
#    'calculations fincial',
#    'charge training',
#    'chinese ctonese',
#    'competencies jul',
#    'competent fincial',
#    'consistent high',
#    'ctonese lguages',
#    'day relationships',
#    'deadlines ensuring',
#    'diploma accounting',
#    'ensuring smooth',
#    'experience hedge',
#    'external valuer',
#    'fincial economic',
#    'fincial statements',
#    'includes preparation',
#    'independent price',
#    'jul trained',
#    'lguages spoken',
#    'lguages written',
#    'liaised external',
#    'magement administration',
#    'maintaining day',
#    'major serget',
#    'matters ensuring',
#    'nearly experience',
#    'operation charge',
#    'preparation cash',
#    'price checks',
#    'price verification',
#    'reconciliations team',
#    'reports consistently',
#    'reports daily',
#    'reuters lguages',
#    'reviewing estimate',
#    'running operation',
#    'serget major',
#    'singapore armed',
#    'singapore artillery',
#    'solving work',
#    'spoken english',
#    'stdards delivering',
#    'stdards fast',
#    'tasks price',
#    'team assist',
#    'team ensure',
#    'trained accounting',
#    'training magement',
#    'training new',
#    'verification external',
#    'written english',
#    'accountt nearly',
#    'accountt present',
#    'accountt processing',
#    'bk reconciliation',
#    'citco dublin',
#    'citco toronto',
#    'delivering nav',
#    'entries reconciliation',
#    'final audit',
#    'final navs',
#    'interim final',
#    'limited accountt',
#    'ltd accountt',
#    'migrations citco',
#    'nav calculations',
#    'nav packages',
#    'nav packs',
#    'position reconciliation',
#    'reconciliation involved',
#    'reconciliation perform',
#    'toronto citco',
#    'fund accountts',
#    'fund calculation',
#    'fund migrations',
#    'fund services',
#    'hedge fund',
#    'new fund',
#    'present fund',
#    'profile fund',
#    'undertaking fund',
#    'battalion singapore',
#    'day day',
#    'ensuring high',
#    'external auditors',
#    'jul operation',
#    'operation battalion',
#    'quality stdards',
#    'quality work',
#    'serget battalion',
#    'work experience',
#    'work stdards',
#    'experience citco',
#    'preparation nav',
#    'reconciliation reports',
#    'final nav',
#    'fund administration',
#    'citco fund',
#    'fund accountt'],
#   'trigrams': ['consistent high quality',
#    'english chinese ctonese',
#    'lguages spoken english',
#    'lguages written english',
#    'spoken english chinese',
#    'written english chinese',
#    'high quality stdards',
#    'high quality work',
#    'ensuring high quality',
#    'calculation estimate final',
#    'estimate final navs',
#    'reviewing estimate final',
#    'accountcy gpa temasek',
#    'accpac myob proficient',
#    'accruals fees booking',
#    'acted level feedback',
#    'alytical problem solving',
#    'ann secondary school',
#    'armed forces specialist',
#    'assisted collecting outstding',
#    'carriers private limited',
#    'certificate skills competencies',
#    'checks interest accruals',
#    'closing accounts liaised',
#    'collecting outstding debts',
#    'consistently meeting deadlines',
#    'daily pre production',
#    'databases thomson reuters',
#    'debts debtors bk',
#    'discipline regimentation fellow',
#    'driven results alytical',
#    'dublin office familiar',
#    'economic databases thomson',
#    'education qualifications royal',
#    'excel powerpoint word',
#    'familiar pricing valuation',
#    'fast learner driven',
#    'feedback peers education',
#    'fees booking maintaining',
#    'fellow nsfs rallied',
#    'fince ngee ann',
#    'forces specialist nsf',
#    'gpa temasek polytechnic',
#    'institute technology rmit',
#    'intercompy journal entries',
#    'interest accruals fees',
#    'investigation resolution breaks',
#    'investment magers brokers',
#    'invoices suppliers scheduling',
#    'involved closing accounts',
#    'learner driven results',
#    'level feedback peers',
#    'levels certificate skills',
#    'lookout troubled soldiers',
#    'melbourne institute technology',
#    'microsoft excel powerpoint',
#    'myob proficient microsoft',
#    'ngee ann secondary',
#    'norgas carriers private',
#    'nsfs rallied superiors',
#    'office familiar pricing',
#    'outstding debts debtors',
#    'packs norgas carriers',
#    'payment remittces assisted',
#    'peers education qualifications',
#    'perform intercompy journal',
#    'powerpoint word competent',
#    'pre production tasks',
#    'pricing valuation models',
#    'processing invoices suppliers',
#    'proficient microsoft excel',
#    'qualifications royal melbourne',
#    'rallied superiors lookout',
#    'regimentation fellow nsfs',
#    'relationships investment magers',
#    'remittces assisted collecting',
#    'responsible welfare discipline',
#    'results alytical problem',
#    'royal melbourne institute',
#    'sage accpac myob',
#    'scheduling payment remittces',
#    'school levels certificate',
#    'secondary school levels',
#    'services pte ltd',
#    'softwares aexeo agresso',
#    'soldiers acted level',
#    'specialist nsf battery',
#    'superiors lookout troubled',
#    'suppliers scheduling payment',
#    'technology rmit bachelor',
#    'temasek polytechnic diploma',
#    'troubled soldiers acted',
#    'valuation models independent',
#    'valuer investigation resolution',
#    'welfare discipline regimentation',
#    'world sage accpac',
#    'estimate final nav',
#    'experience hedge fund',
#    'accounting fince ngee',
#    'accounting softwares aexeo',
#    'accounts liaised external',
#    'accountts team assist',
#    'aexeo agresso business',
#    'agresso business world',
#    'assist reviewing estimate',
#    'associated reports consistently',
#    'audit singapore armed',
#    'auditors communicating reconciliations',
#    'bachelor business accountcy',
#    'basis preparation cash',
#    'battalion responsible welfare',
#    'battery serget major',
#    'booking maintaining day',
#    'breaks training new',
#    'brokers auditors communicating',
#    'business accountcy gpa',
#    'business world sage',
#    'calculations fincial statements',
#    'charge training magement',
#    'communicating reconciliations team',
#    'competencies jul trained',
#    'competent fincial economic',
#    'ctonese lguages written',
#    'day relationships investment',
#    'diploma accounting fince',
#    'ensure consistent high',
#    'ensuring smooth running',
#    'external valuer investigation',
#    'fincial economic databases',
# ...
#    'non listed assets',
#    'group privately held',
#    'money laundering private',
#    'maging director registered',
#    'products maging director',
#    'investment vehicles general',
#    'vehicles general partners',
#    'winterbotham group privately',
#    'direct report fund',
#    'review product creation',
#    'general partners mas',
#    'product creation processes',
#    'qualified practitioner international',
#    'registered resident mager',
#    'resident mager registered',
#    'employees fincial services',
#    'contact investor relations',
#    'investor relations contact',
#    'winterbotham group growth',
#    'fund administrators legal',
#    'fund liaison legal',
#    'funds corporate trusts',
#    'winterbotham group agnes',
#    'account openings bks',
#    'arrgements trade matching',
#    'assets equities trsfer',
#    'brokerage arrgements trade',
#    'brought adopted enhced',
#    'buyout physical offices',
#    'deals negotiation converst',
#    'focuses introduce align',
#    'hong kong strategy',
#    'kong strategy plning',
#    'lguages english chinese',
#    'matching account openings',
#    'networks priy focuses',
#    'partnership listings depending',
#    'priy focuses introduce',
#    'securities settlement brokerage',
#    'settlement brokerage arrgements',
#    'trade matching account',
#    'investor admission closings',
#    'corporate secretarial virtual',
#    'onboarding corporate secretarial',
#    'ing bk group',
#    'international complice anti',
#    'office maging director',
#    'investment vehicles complice',
#    'product creation director',
#    'functions trust compy',
#    'trust compy profit',
#    'practitioner step central',
#    'practitioner step qualified',
#    'step qualified practitioner',
#    'training qualified practitioner',
#    'formation structuring wealth',
#    'reits structuring wealth',
#    'compy resident mager',
#    'funds investment vehicles',
#    'general partners funds',
#    'services industry corporate',
#    'representative fund magers',
#    'corporate trustee services',
#    'corporate trust services',
#    'clients ensuring understding',
#    'point clients ensuring',
#    'estate practitioner society',
#    'adopted enhced ing',
#    'auditors custodis agents',
#    'authorised signatories dealing',
#    'chief executive officer',
#    'competent fields fince',
#    'cost work efficiency',
#    'custodis agents etc',
#    'dealing securities settlement',
#    'equities trsfer agency',
#    'inflows revenue targets',
#    'jurisdiction caym isld',
#    'limited partnership listings',
#    'listings depending jurisdiction',
#    'loss making taking',
#    'main contact point',
#    'openings bks custodis',
#    'ownership scheme achievements',
#    'physical offices major',
#    'portfolio valuation reits',
#    'scheme achievements built',
#    'settlements bking instruments',
#    'share ownership scheme',
#    'signatories dealing securities',
#    'targets met exceeded',
#    'trsfer agency shareholder',
#    'bk public compy',
#    'structure corporate secretarial',
#    'services investment vehicles',
#    'funds listed non',
#    'compy wealth magement',
#    'resident mager trust',
#    'corporate private trusts',
#    'non listed corporate',
#    'actions paying agent',
#    'admission closings investments',
#    'associate dbs bk',
#    'closings lawyers representative',
#    'ensuring understding hdling',
#    'introduce align review',
#    'investments closings custodial',
#    'oversee enforce processes',
#    'review documention procedures',
#    'scope duties board',
#    'trainee hsbc institutional',
#    'cash magement custodi',
#    'societies society trust',
#    'wealth magement corporate',
#    'mas trust compy',
#    'trust compy wealth',
#    'qualified practitioner complice',
#    'sumy operational magement',
#    'ceo asia winterbotham',
#    'documention procedures legal',
#    'liaison legal counsels',
#    'listed assets equities',
#    'orgic growth achieved',
#    'policies brought adopted',
#    'policies oversee enforce',
#    'processing escrows pension',
#    'secretarial virtual cfo',
#    'trades processing escrows',
#    'winterbotham hong kong',
#    'group policies brought',
#    'group policies oversee',
#    'line group policies',
#    'hbc fincial services',
#    'services industry career',
#    'fund magers cash',
#    'wealth magement trust',
#    'services listed non',
#    'complice operations client',
#    'products clients ensuring',
#    'trust estate activities',
#    'chen ceo asia',
#    'chen lguages english',
#    'english chinese agnes',
#    'monetary authority singapore',
#    'nominee resident directorships',
#    'singapore competent fields',
#    'structuring deals negotiation',
#    'understding hdling operations',
#    'valuation reits structuring',
#    'corporate trusts head',
#    'payment services authorised',
#    'mager monetary authority',
#    'strategy plning business',
#    'practitioner complice anti',
#    'trust compy resident',
#    'trust compy singapore',
#    'activities societies society',
#    'employee ownership schemes',
#    'employee share ownership',
#    'experience chief executive',
#    'focus jurisdiction caym',
#    'kyc investors investors',
#    'pension employee ownership',
#    'revenue targets met',
#    'compy employees hbc',
#    'mager trust compy',
#    'agents etc maging',
#    'exceeded maging cost',
#    'compy trust compy',
#    'trust operations client',
#    'director funds corporate',
#    'complice scope duties',
#    'numbers client inflows',
#    'wealth magement services',
#    'client services associate',
#    'client services main',
#    'enforced client services',
#    'office brch fiduciary',
#    'taiw office brch',
#    'cash magement payment',
#    'magers cash magement',
#    'agent bonds debt',
#    'aspects ensuring deliverables',
#    'counsels investment directors',
#    'creation processes line',
#    'dbs bk public',
#    'ensuring deliverables products',
#    'expsion pls product',
#    'mas met enforced',
#    'partners auditors custodis',
#    'paying agent bonds',
#    'relations closings lawyers',
#    'restructuring employee share',
#    'restructuring settlements bking',
#    'services operations client',
#    'director compies resident',
#    'clients fund magers',
#    'caym isld funds',
#    'fund lawyer expertise',
#    'funds labu escrow',
#    'isld funds licensed',
#    'lawyer expertise fund',
#    'lawyers representative fund',
#    'licensed funds labu',
#    'increase operational magement',
#    'operational magement experience',
#    'services public compy',
#    'practitioner trust estate',
#    'development expsion pls',
#    'directors investor counterparts',
#    'escrows pension employee',
#    'executive officer winterbotham',
#    'fincial jurisdictions privately',
#    'major fincial jurisdictions',
#    'offices major fincial',
#    'procedures legal documentation',
#    'profit making growth',
#    'negotiation converst corporate',
#    'services corporate secretarial',
#    'mager corporate trusts',
#    'align review product',
#    'closings investments closings',
#    'partners mas approved',
#    'restructuring paying agencies',
#    'clients ensuring group',
#    'private bkers clients',
#    'achieved employees increase',
#    'chen education central',
#    'chen experience chief',
#    'hdling operations day',
#    'laundering singapore institute',
#    'resident directorships general',
#    'fund magers private',
#    'industry corporate trustee',
#    'complice trust estate',
#    'committee senior magement',
#    'labu escrow trust',
#    'magement buyout physical',
#    'magement committee senior',
#    'magement trainee hsbc',
#    'prior magement buyout',
#    'operational magement review',
#    'corporate trusts director',
#    'achievements built business',
#    'contact point clients',
#    'deliverables products clients',
#    'development teams institutional',
#    'implemented processes policies',
#    'legal counsels investment',
#    'local policies mas',
#    'day activities direct',
#    'day day activities',
#    'investors investors single',
#    'major increase portfolio',
#    'bk group policies',
#    'compy employees bking',
#    'compy profit making',
#    'trusts unit trust',
#    'brch fiduciary services',
#    'services associate dbs',
#    'services authorised signatories',
#    'services networks priy',
#    'services trades processing',
#    'trustee services trades',
#    'virtual cfo services',
#    'estate activities societies',
#    'etc maging revenue',
#    'maging cost work',
#    'maging revenue numbers',
#    'met exceeded maging',
#    'enforce processes operational',
#    'practitioner society trust',
#    'administrators legal secretarial',
#    'industry career growth',
#    'investor counterparts investor',
#    'legal secretarial accounting',
#    'bking instruments private',
#    'client inflows revenue',
#    'client loss making',
#    'complice kyc investors',
#    'limited complice functions',
#    'magers private bkers',
#    'met enforced client',
#    'revenue numbers client',
#    'single client loss',
#    'vehicles complice kyc',
#    'corporate magement services',
#    'office cash magement',
#    'operational magement singapore',
#    'business partners auditors',
#    'head office aside',
#    'work efficiency office',
#    'magement winterbotham hong',
#    'senior magement winterbotham',
#    'corporate trusts magement',
#    'board directors direct',
#    'built team major',
#    'documentation review aspects',
#    'structure documentation review',
#    'team major increase',
#    'employees hbc fincial',
#    'growth achieved employees',
#    'ensuring group local',
#    'processes line group',
#    'office operational magement',
#    'director registered resident',
#    'private trusts unit',
#    'depending jurisdiction funds',
#    'funds portfolio valuation',
#    'making taking fund',
#    'ownership schemes funds',
#    'report fund administrators',
#    'single fund liaison',
#    'magement payment services',
#    'career growth mager',
#    'chen sumy operational',
#    'director office orgic',
#    'legal structure documentation',
#    'making growth built',
#    'relations contact investor',
#    'board director compies',
#    'teams institutional private',
#    'bks custodis corporate',
#    'unit trust fund',
#    'unit trust funds',
#    'group local policies',
#    'efficiency office product',
#    'paying agency debt',
#    'secretarial accounting maging',
#    'structuring fund magement',
#    'operational focus hedge',
#    'operations day day',
#    'services industry magement',
#    'bking industry corporate',
#    'compy singapore competent',
#    'services unit trust',
#    'license mager business',
#    'executive magement committee',
#    'fields fince trust',
#    'institute magement fince',
#    'magement profile executive',
#    'profile executive magement',
#    'trust arm ing',
#    'approved funds investment',
#    'mas approved funds',
#    'partners funds nominee',
#    'office orgic growth',
#    'built business products',
#    'increase portfolio clients',
#    'estate structuring deals',
#    'bonds escrows debt',
#    'escrows paying agency',
#    'growth built team',
#    'investment directors investor',
#    'policies mas met',
#    'paying agencies corporate',
#    'corporate actions paying',
#    'trusts head funds',
#    'client services mager',
#    'fund investor admission',
#    'agency shareholder services',
#    'services limited partnership',
#    'services main contact',
#    'shareholder services limited',
#    'payment services trust',
#    'private institutional clients',
#    'operational aspects ensuring',
#    'processes operational aspects',
#    'product operational focus',
#    'bkers clients client',
#    'practitioner international complice',
#    'converst corporate private',
#    'escrows corporate actions',
#    'private trusts structuring',
#    'bk prior magement',
#    'duties board magement',
#    'hsbc institutional trust',
#    'magement review documention',
#    'funds nominee resident',
#    'mager registered mas',
#    'relationships business partners',
#    'report head office',
#    'head funds corporate',
#    'accounting maging client',
#    'director assistt maging',
#    'agencies corporate trust',
#    'client services magement',
#    'employees bking industry',
#    'legal documentation agnes',
#    'trusts director funds',
#    'industry corporate trust',
#    'office aside maging',
#    'development magement taiw',
#    'industry magement profile',
#    'complice client onboarding',
#    'closings custodial services',
#    'services implemented processes',
#    'team services networks',
#    'focus hedge funds',
#    'funds focus jurisdiction',
#    'investors single fund',
#    'jurisdiction funds focus',
#    'administration fund lawyer',
#    'employees increase operational',
#    'director office single',
#    'authority singapore trust',
#    'lion trust singapore',
#    'singapore institute magement',
#    'singapore trust license',
#    'trust formation structuring',
#    'director board directors',
#    'experience board director',
#    'funds corporate trust',
#    'administration legal structure',
#    'custodial services listed',
#    'expsion office team',
#    'mager lion trust',
#    'trust license mager',
#    'client onboarding corporate',
#    'magement taiw office',
#    'group trust arm',
#    'orgefield group trust',
#    'cfo services resident',
#    'custodi services agnes',
#    'fiduciary services operations',
#    'administration dealing operations',
#    'escrow trust services',
#    'magement custodi services',
#    'trust services orgefield',
#    'review aspects fund',
#    'growth magement winterbotham',
#    'clients escrows paying',
#    'institutional clients escrows',
#    'funds licensed funds',
#    'schemes funds fund',
#    'clients services implemented',
#    'services mager lion',
#    'complice functions trust',
#    'magement complice scope',
#    'team director board',
#    'creation director funds',
#    'singapore limited complice',
#    'services orgefield group',
#    'services payment services',
#    'business products maging',
#    'maging relationships business',
#    'dealing operations office',
#    'operations office cash',
#    'aspects fund investor',
#    'client relationships clients',
#    'client work business',
#    'clients client work',
#    'secretarial services investment',
#    'magement experience board',
#    'registered mas trust',
#    'administration hedge private',
#    'processes policies office',
#    'maging client relationships',
#    'private maging relationships',
#    'services magement trainee',
#    'services trust formation',
#    'relationships clients fund',
#    'magement bonds escrows',
#    'office product operational',
#    'office single client',
#    'board magement team',
#    'trust singapore limited',
#    'trusts structuring administration',
#    'development services expsion',
#    'hedge funds private',
#    'training practitioner trust',
#    'institutional private maging',
#    'listed corporate private',
#    'trust services public',
#    'trust services structure',
#    'trust services unit',
#    'secretarial services office',
#    'funds funds portfolio',
#    'portfolio clients services',
#    'fince trust complice',
#    'structuring administration complice',
#    'services structure corporate',
#    'corporate trust operations',
#    'growth mager corporate',
#    'policies office complice',
#    'complice services payment',
#    'institutional trust services',
#    'fund magement bonds',
#    'services expsion office',
#    'estate funds listed',
#    'singapore office maging',
#    'custodis corporate magement',
#    'office complice operations',
#    'magement team director',
#    'group growth magement',
#    'administration complice client',
#    'services private institutional',
#    'office team services',
#    'magement singapore office',
#    'services escrows corporate',
#    'magement administration services',
#    'trusts magement complice',
#    'administration compy trust',
#    'magement corporate services',
#    'administration services business',
#    'resident director services',
#    'services resident director',
#    'corporate services escrows',
#    'trust structuring fund',
#    'services office operational',
#    'magement trust structuring',
#    'fund magement administration',
#    'director services complice',
#    'trust complice trust',
#    'trust funds funds',
#    'trust fund magement',
#    'magement services private',
#    'magement services corporate',
#    'services complice services'],
#   'most_common_word': 'services',
#   'word_freq': 0.04746835443037975}]

# %%
def get_keywords(field,keyword_list):
    
    l=[]
    
    if type(keyword_list) == str and type(field) == str :
        l.append(main_PreProc(keyword_list))
        element = {'field':field,'keyword_list':l}
    
    elif type(keyword_list) == list and type(field) == str:
        for i in keyword_list:
            l.append(main_PreProc(i))
        element =  {'field':field,'keyword_list':l}
    
    elif type(field) != str:
        raise Error('field must be string')
    return element

# %%
from fuzzywuzzy import fuzz

def word_sim(a,b):
    l =[fuzz.ratio(a,b),fuzz.partial_ratio(a,b),fuzz.token_sort_ratio(a,b),fuzz.token_set_ratio(a,b)]
    if len(a)==len(b):
        l.remove(fuzz.partial_ratio(a,b)) 
        return max(l)
    else:
        return max(l)

# %%
word_sim('data-sciene, machine-learning and deep learning','data')
# Out:
# ('data sciene machine learn deep learning', 100)

# %%
def check_sim_keywords(keywords_dic, word):
    
    for j in keywords_dic.get('keyword_list'):
        
        if word_sim(main_PreProc(j),main_PreProc(word)) >=80 :
            c = 1
            break
        else:
            c = 0
    if c != 0:        
        return keywords_dic.get('keyword_list')
    else:
        raise('no match found')

# %%
from math import log
def tf_idf_(word,d):
    n=0
    counter=[]
    tot_docs = d.count_documents({})
    tf_idf_list=[]
    freq_list=[]
    for i in range(tot_docs):
        tokens = d.find({})[i].get('tokens')
        name=d.find({})[i].get('name')
        c=0
        n=0
        for j in tokens:
            score = word_sim(word,j)
            if score > 80 :
                c=1
                n+=1
        counter.append(c)
        freq_list.append((n/len(tokens),name))
    app_word_tot = sum(counter)    
    if app_word_tot!=0:
        idf = log(tot_docs/app_word_tot)
        for i in freq_list:
            tf_idf_list.append((i[0]*idf,i[1]))
        return tf_idf_list
    else:
        return 'no match'

# %%
import sys
import pymongo
from pymongo import MongoClient
Client = MongoClient("mongodb+srv://misooo123:miso1212@nlpintern.9ghch.mongodb.net/Resume?retryWrites=true&w=majority")

db = Client.NLPIntern

tf_idf_('data',db.Resume)
# Out:
# [(0.0009375779466983603, 'amy'),
#  (0.0023004489826207192, 'cv-labia-oumaima'),
#  (0.0, 'cv'),
#  (0.012272895322281537, 'cvmohameel-eliem'),
#  (0.009270058511569545, 'resumehajjajiima')]

# %%
tf_idf_(main_PreProc('finance'),db.Resume)
# Out:
# [(0.007699922116589538, 'amy'),
#  (0.0, 'cv-labia-oumaima'),
#  (0.0, 'cv'),
#  (0.0, 'cvmohameel-eliem'),
#  (0.008156890788197226, 'resumehajjajiima')]

# %%
tf_idf_(main_PreProc('data science and machine learning'),db.Resume)
# Out:
# [(0.0, 'amy'),
#  (0.0, 'cv-labia-oumaima'),
#  (0.0, 'cv'),
#  (0.0, 'cvmohameel-eliem'),
#  (0.0, 'resumehajjajiima')]

# %%
tf_idf_(main_PreProc('mathematics, probabilty and statistics'),db.Resume)
# Out:
# [(0.0, 'amy'),
#  (0.028964339491886072, 'cv-labia-oumaima'),
#  (0.0, 'cv'),
#  (0.01787889683180968, 'cvmohameel-eliem'),
#  (0.010610621265168946, 'resumehajjajiima')]

# %%
data = get_keywords('data',['machine-learning','data-science','data-engineering','mathematics','data','SQL',
                         'NOSQL','deep-learning','statistic descriptive','github','kaggle','linear regression',
                         'artifical intellgience','monte-carlo','AI','data-wrangling','data-vizualisation'])
data
# Out:
# {'field': 'data',
#  'keyword_list': ['machine learning',
#   'data science',
#   'data engineering',
#   'mathematics',
#   'data',
#   'sql',
#   'nosql',
#   'deep learning',
#   'statistic descriptive',
#   'github',
#   'kaggle',
#   'linear regression',
#   'artifical intellgience',
#   'monte carlo',
#   'ai',
#   'data wrgling',
#   'data vizualisation']}

# %%
word_to_check = check_sim_keywords(data,'machine learning engineer')

# %%
for i in word_to_check:
    print(tf_idf_(i,db.Resume),i)
# Out:
# [(0.0, 'amy'), (0.0, 'cv-labia-oumaima'), (0.0, 'cv'), (0.0, 'cvmohameel-eliem'), (0.0, 'resumehajjajiima')] machine learning
# [(0.0, 'amy'), (0.0023004489826207192, 'cv-labia-oumaima'), (0.010012851661535054, 'cv'), (0.015620048591994685, 'cvmohameel-eliem'), (0.011918646657732271, 'resumehajjajiima')] data science
# [(0.0, 'amy'), (0.0046008979652414385, 'cv-labia-oumaima'), (0.011443259041754347, 'cv'), (0.013388613078852585, 'cvmohameel-eliem'), (0.011918646657732271, 'resumehajjajiima')] data engineering
# [(0.0, 'amy'), (0.0052662435439792855, 'cv-labia-oumaima'), (0.0, 'cv'), (0.007662384356489861, 'cvmohameel-eliem'), (0.0030316060757625564, 'resumehajjajiima')] mathematics
# [(0.0009375779466983603, 'amy'), (0.0023004489826207192, 'cv-labia-oumaima'), (0.0, 'cv'), (0.012272895322281537, 'cvmohameel-eliem'), (0.009270058511569545, 'resumehajjajiima')] data
# [(0.0, 'amy'), (0.004723148102444098, 'cv-labia-oumaima'), (0.0, 'cv'), (0.009162907318741552, 'cvmohameel-eliem'), (0.0, 'resumehajjajiima')] sql
# [(0.0, 'amy'), (0.0026331217719896428, 'cv-labia-oumaima'), (0.0, 'cv'), (0.005108256237659908, 'cvmohameel-eliem'), (0.0030316060757625564, 'resumehajjajiima')] nosql
# [(0.0, 'amy'), (0.0, 'cv-labia-oumaima'), (0.0, 'cv'), (0.0, 'cvmohameel-eliem'), (0.0, 'resumehajjajiima')] deep learning
# [(0.0, 'amy'), (0.009201795930482877, 'cv-labia-oumaima'), (0.005721629520877174, 'cv'), (0.0044628710262841955, 'cvmohameel-eliem'), (0.0033107351827034092, 'resumehajjajiima')] statistic descriptive
# [(0.0, 'amy'), (0.0, 'cv-labia-oumaima'), (0.0, 'cv'), (0.0, 'cvmohameel-eliem'), (0.009551560311181604, 'resumehajjajiima')] github
# [(0.0, 'amy'), (0.0, 'cv-labia-oumaima'), (0.010316909695090385, 'cv'), (0.0, 'cvmohameel-eliem'), (0.0, 'resumehajjajiima')] kaggle
# [(0.0009375779466983603, 'amy'), (0.008051571439172516, 'cv-labia-oumaima'), (0.0, 'cv'), (0.0044628710262841955, 'cvmohameel-eliem'), (0.0052971762923254544, 'resumehajjajiima')] linear regression
# [(0.0, 'amy'), (0.0, 'cv-labia-oumaima'), (0.029470709063422543, 'cv'), (0.010216512475319815, 'cvmohameel-eliem'), (0.010610621265168946, 'resumehajjajiima')] artifical intellgience
# [(0.0, 'amy'), (0.0, 'cv-labia-oumaima'), (0.0, 'cv'), (0.004581453659370776, 'cvmohameel-eliem'), (0.016313781576394452, 'resumehajjajiima')] monte carlo
# [(0.0, 'amy'), (0.0, 'cv-labia-oumaima'), (0.0, 'cv'), (0.0, 'cvmohameel-eliem'), (0.0, 'resumehajjajiima')] ai
# [(0.0, 'amy'), (0.0052662435439792855, 'cv-labia-oumaima'), (0.0, 'cv'), (0.022987153069469583, 'cvmohameel-eliem'), (0.02425284860610045, 'resumehajjajiima')] data wrgling
# [(0.0, 'amy'), (0.007899365315968928, 'cv-labia-oumaima'), (0.0, 'cv'), (0.025541281188299538, 'cvmohameel-eliem'), (0.02880025771974428, 'resumehajjajiima')] data vizualisation

# %%
import sys
import pymongo
from pymongo import MongoClient
Client = MongoClient("mongodb+srv://misooo123:miso1212@nlpintern.9ghch.mongodb.net/Resume?retryWrites=true&w=majority")

db = Client.NLPIntern
C = db.text_cat
cur = db.Resume.find({}, {'trigrams': '','id':'0'})
db.Resume.count_documents({})
# Out:
# 5

# %%
import sys
import pymongo
from pymongo import MongoClient
from collections import Counter

def mongo_db_insert_raw_text(connection_string, path):

    client = MongoClient(connection_string) 
    db = client.NLPIntern
    col = db.Resume
    
    to_insert = insert_text_into(path) 
    
    if type(to_insert) == dict : 
        col.insert_one(to_insert)

    elif type(to_insert) == list : 
        col.insert_many(to_insert)



""" 
        
def mongo_db_cat_text(connection_string):
    
    client = MongoClient(connection_string)
    db = client.NLPIntern
    C = db.text_cat
    Cursor = db.Resume.find({} ,{'raw_text' : '', 'name':'' })
    
    for i in Cursor :
        
        
        
        preproceced_text = main_PreProc(i.get('raw_text'))
        tokens = tokenizer(preproceced_text)
        counter = Counter(tokens)
        bigrams = bigrams_(preproceced_text,tokens)
        trigrams = trigrams_(preproceced_text,tokens)
        most_freq = counter.most_common(1)
        element = {
                    'name': i.get('name'),
                    'preproceced_text' : preproceced_text,
                    'tokens' : tokens,
                    'bigrams' : bigrams,
                    'trigrams' : trigrams,
                    'most_common_word' : most_freq,
                    'word_freq' : most_freq[0][1]/len(tokens),
                    
                   }
        
        C.insert_one(element)

      
def mongo_db_tokenizer_text(connection_string):

    client = MongoClient(connection_string)
    db = client.NLPIntern
    C = db.text_cat
    Cursor = db.text_cat.find({} ,{'preproceced_text' : '' })
    l = []
    for i in Cursor :
        tokens = tokenizer(i.get('preproceced_text'))
        element = {
                    'tokens' : tokens
                   }
        l.append(element)
    for i in range(len(l)):
        C.update( {},  { "$set": l[i] })
    
            
def mongo_db_bigrams(connection_string):
    client = MongoClient(connection_string) 
    db = client.NLPIntern
    C = db.text_cat
    Cursor = db.text_cat.find({} , { 'preproceced_text' : '' , 'tokens': [] })
    l=[]
    for i in Cursor :
        bigrams = bigrams_(i.get('preproceced_text'), i.get('tokens'))
        element = {
                    'bigrams' : bigrams
                   }
        l.append(element)
    for i in range(len(l)) : 
        C.update_one( {},  { "$set": l[i] })
        
            
def mongo_db_trigrams(connection_string):
    client = MongoClient(connection_string) 
    db = client.NLPIntern
    C = db.text_cat
    Cursor = db.text_cat.find({} , { 'preproceced_text' : '' , 'tokens': [] })
    
    for i in Cursor :
        trigrams = trigrams_(i.get('preproceced_text'), i.get('tokens'))
        element = {
                    'trigrams' : trigrams
                   }
        C.update_one(  {},  { "$set": trigrams})
            """

# %%
mongo_db_insert_raw_text("mongodb+srv://misooo123:miso1212@nlpintern.9ghch.mongodb.net/Resume?retryWrites=true&w=majority", r'..\stage\doubled')

# %%
#mongo_db_cat_text("mongodb+srv://misooo123:miso1212@nlpintern.9ghch.mongodb.net/Resume?retryWrites=true&w=majority")
